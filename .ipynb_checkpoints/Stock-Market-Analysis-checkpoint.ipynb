# %% [markdown]
# # Stock Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
from pandas.io.data import DataReader
# Scrapes stocks from internet

# %%
from datetime import datetime
from __future__ import division

# %%
tech_list = ['AAPL', 'GOOG', 'MSFT', 'AMZN']
# Apple, Google, Microsoft and Amazon

# %% [markdown]
# ## Stock Performance of Apple

# %%
end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)
# Datetime is essentially a tuple (y,m,d,h,m,s)

# %%
for stock in tech_list :
    globals()[stock] = DataReader(stock, 'yahoo', start, end)
    
# globals()[X] assigns stock string as a global variable (dataframe in this case)
# DataReader reads the list of ticks from yahoo

# %%
plt.figure(figsize=(12,5))
ax = AAPL['Adj Close'].plot(legend=True)
ax.set_xlabel('Date', fontsize=15)
ax.set_ylabel('USD/$', fontsize=15)

ax.set_title("Apple Stocks Adjusted Close Price", fontsize=15, weight='bold')

# %% [markdown]
# The adjusted close position of Apple stocks over the past year.

# %%
plt.figure(figsize=(12,5))
ax = AAPL['Volume'].plot(legend=True, color='darkgreen', alpha=0.8)
ax.set_xlabel('Date', fontsize=15)
ax.set_ylabel('Volume', fontsize=15)

ax.set_title("Apple Stocks Traded by Volume", fontsize=15, weight='bold')

# %% [markdown]
# The volume of Apple stocks traded over the past year.

# %%
ma_day = [10, 20, 50]

for ma in ma_day :
    column_name = "MA for %d days" % ma
    AAPL[column_name] = pd.rolling_mean(AAPL['Adj Close'], ma)
    
# Insert a column for 10, 20 and 50 point moving averages

# %%
ax = AAPL[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(subplots=False,figsize=(12,5))
ax.set_xlabel('Date', fontsize=15)
ax.set_ylabel('USD/$', fontsize=15)

ax.set_title("Moving Averages for Apple Stocks", fontsize=15, weight='bold')

# %%
AAPL['Daily Return'] = AAPL['Adj Close'].pct_change()
# % change is already a pandas method

# %%
plt.figure(figsize=(12,5))
ax = AAPL['Daily Return'].plot( legend=True, color='grey',linestyle='-', marker='^')
ax.set_xlabel('Date', fontsize=15)
ax.set_ylabel('%', fontsize=15)

ax.set_title("Daily Returns for Apple Stocks", fontsize=15, weight='bold')

# %% [markdown]
# Daily returns as a lineplot is too messy.

# %%
plt.figure(figsize=(7,7))

ax = sns.distplot(AAPL['Daily Return'].dropna(), bins=100, color='purple')
ax.set_xlabel('Daily Return', fontsize=15)
ax.set_ylabel('Count', fontsize=15)

ax.set_title("Histogram and KDE for Apple Daily Returns", fontsize=15, weight='bold')

# %% [markdown]
# Daily returns as a distribution/histogram is more informative. We can see the modal value is below zero, but the distribution seems skewed in the positive direction.

# %% [markdown]
# ## Correlations between Tech Companies

# %%
closing_df = DataReader(tech_list, 'yahoo', start, end)['Adj Close']
# One dataframe for all tech_list companies, adj close data

# %%
tech_rets = closing_df.pct_change()

# %%
sns.set_style("dark")
ax = sns.jointplot(x='GOOG', y='AAPL', data=tech_rets, kind='scatter', color='seagreen')

# %% [markdown]
# A joint scatterplot for Google and Apple daily returns.
#
# N.B. (|r| < 0.3) -> weak correlation; (0.3 < |r| < 0.5) -> medium correlation; (|r| > 0.5) -> strong correlation.

# %%
sns.set(style='ticks')
ax = sns.pairplot(tech_rets.dropna(), diag_kind='hist')

nplot = len(tech_rets.columns)
for i in range(nplot) :
    for j in range(nplot) :
        ax.axes[i, j].locator_params(axis='x', nbins=6, tight=True)
#ax.axes is now a matrix

# %%
ax = sns.PairGrid(tech_rets.dropna())
ax.map_upper(plt.scatter, color='purple')
ax.map_lower(sns.kdeplot, color='hlr')
ax.map_diag(plt.hist, bins=30)
for i in range(nplot) :
    for j in range(nplot) :
        ax.axes[i, j].locator_params(axis='x', nbins=6, tight=True)

# %% [markdown]
# pairplot is nice and easy scatterplots for all columns in a dataframe (diag is histogram), whilst PairGrid is more customisable. corrplot explicitly calculates the coefficients.

# %%
plt.figure(figsize=(7,7))
ax = sns.corrplot(tech_rets.dropna(), annot=True)

# %% [markdown]
# Google, Microsoft and Amazon all have a strong correlation with each other, but Apple only has a strong correlation with Microsoft.

# %% [markdown]
# ## Risk Analysis

# %% [markdown]
# There are many ways to define risk. Standard deviation is a good indicator of risk for a stock's behaviour.

# %%
rets = tech_rets.dropna()
area = np.pi*20.0

sns.set(style='darkgrid')
plt.figure(figsize=(9,9))
plt.scatter(rets.mean(), rets.std(), s=area)
plt.xlabel("Expected Return", fontsize=15)
plt.ylabel("Risk", fontsize=15)
plt.title("Return vs. Risk for Tech. Stocks", fontsize=20)

for label, x, y in zip(rets.columns, rets.mean(), rets.std()) : 
    plt.annotate(label, xy=(x,y), xytext=(50, 0), textcoords='offset points',
                arrowprops=dict(arrowstyle='-', connectionstyle='bar,angle=180,fraction=-0.2'),
                bbox=dict(boxstyle="round", fc="w"))

# %% [markdown]
# We see that Amazon gives both the best average return and the highest risk. Apple has an average return of less than zero (not good!)

# %% [markdown]
# ### Value at Risk
#
# What is the most we can expect to lose on a given stock? We could define it as the quantile of the lower x% of the distribution, the VaR (x%). The bootstrap method takes it from the past performance of the stock, whilst the Monte Carlo method tries to simulate the future.

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(7,7))
ax = sns.distplot(AAPL['Daily Return'].dropna(), bins=100, color='red')
ax.set_xlabel('Daily Return', fontsize=15)
ax.set_ylabel('Count', fontsize=15)

ax.set_title("Histogram and KDE for Apple Daily Returns", fontsize=15, weight='bold')

# %%
rets.quantile(0.05) # 5% Quantile
# Out:
# AAPL   -0.028032
# AMZN   -0.032752
# GOOG   -0.023431
# MSFT   -0.024520
# dtype: float64

# %%
rets.quantile(0.95) # 95% Quantile
# Out:
# AAPL    0.027223
# AMZN    0.031655
# GOOG    0.025348
# MSFT    0.023139
# dtype: float64

# %% [markdown]
# The worst 5% of results, have lost 2.8% of the Apple stock price in a day, i.e. the '5% Value at Risk' is 2.8%. On the other hand, the best 5% of results only give you a gain of 2.7%, so the distribution is skewed somewhat. As seen in the risk scatterplot, Amazon has the highest risk.

# %% [markdown]
# ### Monte Carlo Approach

# %% [markdown]
# The geometric Brownian motion model:
#
# <a href="https://www.codecogs.com/eqnedit.php?latex=\large&space;\Delta&space;S&space;=&space;S(\mu\Delta&space;t&space;&plus;&space;\sigma\epsilon&space;\sqrt[]{\Delta&space;t})" target="_blank"><img src="https://latex.codecogs.com/gif.latex?\large&space;\Delta&space;S&space;=&space;S(\mu\Delta&space;t&space;&plus;&space;\sigma\epsilon&space;\sqrt[]{\Delta&space;t})" title="\large \Delta S = S(\mu\Delta t + \sigma\epsilon \sqrt[]{\Delta t})" /></a>
#
# N.B. Use https://www.codecogs.com/latex/eqneditor.php for formulae.

# %% [markdown]
# S is the change in share price, mu is the expected return, t is time, sigma is standard deviation of returns, epsilon is a random number. The first term is a deterministic 'drift' term, the second is a stochastic 'shock' term.
#
# If we simulate many final states of the system and put the results into bins, we can create a probability distribution function to give us an idea of what the stock price could be in a year. This simulation is of last year's performance, to compare with the actual current price.

# %%
# Parameters
days=365
dt=1 # dt is one day
mu=rets.mean()['GOOG']
sigma=rets.std()['GOOG']

# %%
def stock_monte_carlo(start_price, days, mu, sigma) :
    
    price=np.zeros(days)
    price[0] = start_price
    
    shock=np.zeros(days)
    drift=np.zeros(days)
    
    for x in xrange(1, days) :
        drift[x]=mu*dt
        shock[x]=np.random.normal(loc=0.0, scale=sigma*np.sqrt(dt))
        #  = sigma*np.sqrt(dt)*np.random.randn()
        price[x] = price[x-1] + price[x-1]*(drift[x] + shock[x])
        
    return price

# %%
start_price = GOOG.ix[0][0] # The stock price this time last year
start_price
# Out:
# 538.21002199999998

# %%
N = len(GOOG)
end_price = GOOG.ix[N-1][0]
end_price
# Out:
# 690.48999000000003

# %%
sns.set_style("whitegrid")

for i in range(100) :
    plt.plot(stock_monte_carlo(start_price, days, mu, sigma), alpha=0.7)
    
plt.plot([0, 365], [start_price, start_price], 'k--')
plt.xlabel("Days", fontsize=15)
plt.ylabel("Price", fontsize=15)

plt.title("Monte Carlo Analysis for Google Stocks", fontsize=15, weight='bold')

# %%
runs = 100000
simulations_goog=np.zeros(runs)

for run in range(runs) :
    simulations_goog[run] = stock_monte_carlo(start_price, days, mu, sigma)[days-1]

# %% [markdown]
# A bigger simulation to create a histogram and KDE for our stock price distribution.

# %%
q = np.percentile(simulations_goog, 1)

sns.set_style("whitegrid")
plt.figure(figsize=(8,8))
plt.hist(simulations_goog, bins=200)

plt.figtext(0.62, 0.85, s="Starting Price = $%.2f" % start_price)
plt.figtext(0.62, 0.81, s="Mean Final Price = $%.2f" % simulations_goog.mean())
plt.figtext(0.62, 0.77, s="VaR (99pc) = $%.2f" % (start_price-q))
plt.figtext(0.22, 0.85, s="1pc Quantile = $%.2f" % q)

plt.axvline(x=q, linewidth=2, color='r', linestyle='--')
#plt.axvline(x=start_price, linewidth=2, color='w', linestyle='--')

plt.xlabel("Price", fontsize=15)
plt.title("Distribution of Google stock after %d days" % days, weight='bold', fontsize=15)

# %%
VaR_goog = (start_price-q)*100/start_price
mu, sigma, VaR_goog, np.median(simulations_goog)
# Out:
# (0.0012533044487350021,
#  0.019253696382360883,
#  37.194113994775179,
#  793.98977118813923)

# %%
from scipy import stats
stats.percentileofscore(simulations_goog, end_price)
# Out:
# 35.248000000000005

# %% [markdown]
# The VaR (99%) is then 37.2%, for each stock you buy we predict that if things go badly, that is the most you can expect to lose... (99% of the time). The mean final price is \$849.40, much higher than the actual end price of \$690.45, which lies in the lower 35.2% of final prices.

# %% [markdown]
# ## Stock Analysis of Other Sectors

# %% [markdown]
# Let's have a look at risk for some companies from different sectors.

# %%
diverse_list = ['XOM', 'GS', 'TYO', 'RIO', 'WFM']
# Exxon Mobil (Oil), Goldman Sachs (Finance), Toyota (Manufacturing), Rio Tinto (Mining) and Whole Foods (Retail)

# %%
end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)

diverse_prices = DataReader(diverse_list, 'yahoo', start, end)['Adj Close']
diverse_rets = diverse_prices.pct_change()
diverse_rets = diverse_rets.dropna()

# %% [markdown]
# ### Standard Deviation as Risk

# %%
area = np.pi*20.0

sns.set(style='darkgrid')
plt.figure(figsize=(9,9))
plt.scatter(diverse_rets.mean(), diverse_rets.std(), s=area)
plt.xlabel("Expected Return", fontsize=15)
plt.ylabel("Risk", fontsize=15)
plt.title("Return vs. Risk for Diverse Stocks", fontsize=20, weight='bold')

for label, x, y in zip(diverse_rets.columns, diverse_rets.mean(), diverse_rets.std()) : 
    plt.annotate(label, xy=(x,y), xytext=(50, 0), textcoords='offset points',
                arrowprops=dict(arrowstyle='-', connectionstyle='bar,angle=180,fraction=-0.2'),
                bbox=dict(boxstyle="round", fc="w"))

# %% [markdown]
# The diverse list has been doing much worse than the tech. list. Exxon is the only company to have a positive average return.

# %%
diverse_rets.quantile(0.05)
# Out:
# GS    -0.030765
# RIO   -0.042577
# TYO   -0.019848
# WFM   -0.024185
# XOM   -0.021716
# dtype: float64

# %% [markdown]
# Rio Tinto has the highest VaR (5%) by a large margin, 4.3% of the stock price. Exxon has a low VaR and positive expected return, so it is the most appealing stock out of the bunch.
#
# We can try and simulate Rio Tinto's current stock price.

# %% [markdown]
# ### MC Simulation

# %%
# Parameters
start_price = diverse_prices['RIO'][0] # Rio Tinto's adj close this time last year
mu = diverse_rets['RIO'].mean()
sigma = diverse_rets['RIO'].std()

# %%
runs = 100000
simulations_rio=np.zeros(runs)

for run in range(runs) :
    simulations_rio[run] = stock_monte_carlo(start_price, days, mu, sigma)[days-1]

# %%
q = np.percentile(simulations_rio, 1)

sns.set_style("whitegrid")
plt.figure(figsize=(8,8))
plt.hist(simulations_rio, bins=200)

plt.figtext(0.62, 0.85, s="Starting Price = $%.2f" % start_price)
plt.figtext(0.62, 0.81, s="Mean Final Price = $%.2f" % simulations_rio.mean())
plt.figtext(0.62, 0.77, s="VaR (99pc) = $%.2f" % (start_price-q))
plt.figtext(0.2, 0.85, s="1pc Quantile = $%.2f" % q)

plt.axvline(x=q, linewidth=2, color='r', linestyle='--')
#plt.axvline(x=start_price, linewidth=2, color='w', linestyle='--')

plt.xlabel("Price", fontsize=15)
plt.title("Distribution of Rio Tinto stock after %d days" % days, weight='bold', fontsize=15)

# %%
VaR_rio = (start_price-q)*100/start_price
end_price = diverse_prices['RIO'][len(diverse_prices)-1]
VaR_rio, end_price, np.median(simulations_rio)
# Out:
# (82.13116155951532, 30.549999, 26.199284877394348)

# %%
stats.percentileofscore(simulations_rio, end_price)
# Out:
# 61.578999999999994

# %% [markdown]
# The VaR (99%) is 82.13% of the stock value (as opposed to Google's 37.4%). The mean final price \$30.06 is actually very close to the actual final price of \$30.55.

# %% [markdown]
# ## Correlations Between Other Sectors
#
# Are there any correlations between these companies?

# %%
sns.set_style("ticks")
ax = sns.PairGrid(diverse_rets.dropna())
ax.map_upper(plt.scatter, color='darkred')
ax.map_lower(sns.kdeplot, cmap='rainbow_r')
ax.map_diag(sns.kdeplot)
nplot = len(diverse_rets.columns)
for i in range(nplot) :
    for j in range(nplot) :
        ax.axes[i, j].locator_params(axis='x', nbins=6, tight=True)

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(7,7))
ax = sns.corrplot(diverse_rets.dropna(), annot=True)

# %% [markdown]
# Seems that Goldman, Exxon and Rio Tinto all have strong correlation. All others have weak correlation, aside from a medium correlation between Goldman and Toyota.
